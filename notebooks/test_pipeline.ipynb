# %% [markdown]
# # Test Pipeline DermaScan AI
# Notebook này dùng để chạy thử từng mô-đun riêng lẻ (YOLOv8, DenseNet, Grad-CAM) trong quá trình nghiên cứu.

# %%
import os
import sys
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Thêm thư mục backend vào Python path để import
sys.path.append(os.path.abspath('../backend'))

from app.config import CLASS_NAMES
from app.services.yolo_detector import YOLODetector
from app.services.densenet_classifier import DenseNetClassifier
from app.services.gradcam_engine import GradCAMEngine
from app.utils.image_helper import crop_bounding_boxes, blend_all

print("Các thư viện và dịch vụ đã import thành công!")
